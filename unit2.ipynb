# %% [markdown]
# # Unit 2
# ---
#
#
#
#
# 1. [Introducing Pandas](#section1)
# 2. [Reading files](#section2)
# 3. [Selecting data](#section3)
# 4. [Conditional selection](#section4)

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## 1. Introducing Pandas
# ---
#
# <div>
# <img src="images/pandas.JPG" width="400"/>
# </div>
#
#
#
# [Panda's documentation](https://pandas.pydata.org/pandas-docs/stable/)

# %% [markdown]
# To begin we need to import pandas
# When you see pd, know it is referring to pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas is a popular Python library used for working in tabular data (similar to the data stored in a spreadsheet).
#
# There are two main data structure used by pandas
# - Series: like a vector or a list
# - Dataframe: equivalent to a table.
#
# Each column in a pandas Dataframe is a pandas Series data structure. We will mainly be looking at the Dataframe.
#
# We can easily create a Pandas Dataframe by reading a .csv file

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## 2. Reading files
# ---
#
# <div>
# <img src="images/reading.PNG" width="400"/>
# </div>
#
#
# We will read the whole file at once using Pandas.
# Sometimes you might want to read the file line by line, and process each line. Thats possible of course. See for example [here.](https://www.geeksforgeeks.org/read-a-file-line-by-line-in-python/)
#
# We will read data on [COVID-19 vaccinations](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations)
#
# In order to do that, I retrieved the raw data's url
#
# <div>
# <img src="images/raw.png" width="800"/>
# </div>

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)

# %% [markdown]
# read_csv has about 30 different options. See the
# [documentation](https://pandas.pydata.org/pandasdocs/stable/reference/api/pandas.read_csv.html#pandas.read_csv)
#
# For example, sep='\t' is used for tab delimited files and 'usecol' reads only specific columns.

# %%
type(vacc_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# view the shape of the dataframe:

# %%
vacc_df.shape
# Out:
# (24330, 12)

# %% [markdown]
# view basic information:

# %%
vacc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24330 entries, 0 to 24329
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             24330 non-null  object
#  1   iso_code                             24330 non-null  object
#  2   date                                 24330 non-null  object
#  3   total_vaccinations                   14631 non-null  float64
#  4   people_vaccinated                    13856 non-null  float64
#  5   people_fully_vaccinated              11021 non-null  float64
#  6   daily_vaccinations_raw               12443 non-null  float64
#  7   daily_vaccinations                   24090 non-null  float64
#  8   total_vaccinations_per_hundred       14631 non-null  float64
#  9   people_vaccinated_per_hundred        13856 non-null  float64
#  10  people_fully_vaccinated_per_hundred  11021 non-null  float64
#  11  daily_vaccinations_per_million       24090 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 2.2+ MB

# %%
vacc_df.columns
# Out:
# Index(['location', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations_per_million'],
#       dtype='object')

# %% [markdown]
# View the first few rows:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %% [markdown]
# What do you think that the 'tail' command does? Try it out!
#
# What happens if we just type vacc_df, without a head or a tail?

# %%
vacc_df.tail()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 24325  Zimbabwe      ZWE  2021-05-30           1011973.0           670755.0
# 24326  Zimbabwe      ZWE  2021-05-31           1020078.0           675678.0
# 24327  Zimbabwe      ZWE  2021-06-01           1031281.0           678003.0
# 24328  Zimbabwe      ZWE  2021-06-02           1040214.0           682242.0
# 24329  Zimbabwe      ZWE  2021-06-03           1048504.0           684164.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 24325                 341218.0                  9508.0             14420.0
# 24326                 344400.0                  8105.0             15022.0
# 24327                 353278.0                 11203.0             14756.0
# 24328                 357972.0                  8933.0             14739.0
# 24329                 364340.0                  8290.0             13588.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 24325                            6.81                           4.51
# 24326                            6.86                           4.55
# 24327                            6.94                           4.56
# 24328                            7.00                           4.59
# 24329                            7.05                           4.60
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 24325                                 2.30                           970.0
# 24326                                 2.32                          1011.0
# 24327                                 2.38                           993.0
# 24328                                 2.41                           992.0
# 24329                                 2.45                           914.0

# %%
vacc_df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.463100e+04       1.385600e+04             1.102100e+04
# mean         2.790308e+07       1.536417e+07             8.402886e+06
# std          1.201839e+08       5.929308e+07             3.237196e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.069170e+05       8.282900e+04             3.833300e+04
# 50%          8.425210e+05       6.153600e+05             3.258600e+05
# 75%          5.115514e+06       3.610266e+06             1.997670e+06
# max          2.091618e+09       8.869726e+08             4.542465e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.244300e+04        2.409000e+04
# mean             6.770069e+05        3.421066e+05
# std              2.670817e+06        1.801534e+06
# min              0.000000e+00        0.000000e+00
# 25%              4.733500e+03        9.440000e+02
# 50%              2.607200e+04        7.712000e+03
# 75%              1.544095e+05        4.591225e+04
# max              4.016530e+07        3.514987e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    14631.000000                   13856.000000
# mean                        19.810776                      13.520662
# std                         27.092866                      17.076075
# min                          0.000000                       0.000000
# 25%                          1.720000                       1.430000
# 50%                          8.510000                       6.160000
# 75%                         27.030000                      19.420000
# max                        230.680000                     116.050000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         11021.000000                    24090.000000
# mean                              7.529066                     3125.697592
# std                              11.620442                     4464.634937
# min                               0.000000                        0.000000
# 25%                               0.640000                      350.000000
# 50%                               2.960000                     1615.000000
# 75%                               9.290000                     4445.000000
# max                             114.630000                   118759.000000

# %% [markdown]
# A summary of the functions so far:
#
# * `pd.read_csv` - Read data from a CSV file into a Pandas `DataFrame` object
# * `.info()` - View basic infomation about rows, columns & data types
# * `.describe()` - View statistical information about numeric columns
# * `.columns` - Get the list of column names
# * `.shape` - Get the number of rows & columns as a tuple
# * `.head`, `.tail`

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ---
# ## 3. Selecting data
#
# ![](https://i.imgur.com/zfxLzEv.png)

# %%
# Pandas format is NOT similar to this
covid_data_list = [
    {'date': '2020-08-30', 'new_cases': 1444, 'new_deaths': 1, 'new_tests': 53541},
    {'date': '2020-08-31', 'new_cases': 1365, 'new_deaths': 4, 'new_tests': 42583},
    {'date': '2020-09-01', 'new_cases': 996, 'new_deaths': 6, 'new_tests': 54395},
    {'date': '2020-09-02', 'new_cases': 975, 'new_deaths': 8 },
    {'date': '2020-09-03', 'new_cases': 1326, 'new_deaths': 6},
]
covid_data_list
# Out:
# [{'date': '2020-08-30',
#   'new_cases': 1444,
#   'new_deaths': 1,
#   'new_tests': 53541},
#  {'date': '2020-08-31',
#   'new_cases': 1365,
#   'new_deaths': 4,
#   'new_tests': 42583},
#  {'date': '2020-09-01', 'new_cases': 996, 'new_deaths': 6, 'new_tests': 54395},
#  {'date': '2020-09-02', 'new_cases': 975, 'new_deaths': 8},
#  {'date': '2020-09-03', 'new_cases': 1326, 'new_deaths': 6}]

# %%
# Pandas format is simliar to this
covid_data_dict = {
    'date':       ['2020-08-30', '2020-08-31', '2020-09-01', '2020-09-02', '2020-09-03'],
    'new_cases':  [1444, 1365, 996, 975, 1326],
    'new_deaths': [1, 4, 6, 8, 6],
    'new_tests': [53541, 42583, 54395, None, None]
}

# %% [markdown]
# #### The index of a dataframe doesn't have to be numeric

# %%
df = pd.DataFrame({'age':[30, 2, 12, 4, 32, 33, 69],
                   'color':['blue', 'green', 'red', 'white', 'gray', 'black', 'red'],
                   'food':['Steak', 'Lamb', 'Mango', 'Apple', 'Cheese', 'Melon', 'Beans'],
                   'height':[165, 70, 120, 80, 180, 172, 150],
                   'score':[4.6, 8.3, 9.0, 3.3, 1.8, 9.5, 2.2],
                   'state':['NY', 'TX', 'FL', 'AL', 'AK', 'TX', 'TX']
                   },
                  index=['Jane', 'Nick', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'])
df
# Out:
#            age  color    food  height  score state
# Jane        30   blue   Steak     165    4.6    NY
# Nick         2  green    Lamb      70    8.3    TX
# Aaron       12    red   Mango     120    9.0    FL
# Penelope     4  white   Apple      80    3.3    AL
# Dean        32   gray  Cheese     180    1.8    AK
# Christina   33  black   Melon     172    9.5    TX
# Cornelia    69    red   Beans     150    2.2    TX

# %% [markdown]
# In our case it just happens to be numeric:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
vacc_df.location
#is the same as this:
vacc_df['location']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 24325       Zimbabwe
# 24326       Zimbabwe
# 24327       Zimbabwe
# 24328       Zimbabwe
# 24329       Zimbabwe
# Name: location, Length: 24330, dtype: object

# %% [markdown]
# note: using the `.` notation is possible only for columns whose names do not contain spaces or special characters

# %% [markdown]
# what data type is vacc_df.location? (list? series? dataframe?)

# %%
type(vacc_df.location)
# Out:
# pandas.core.series.Series

# %%
#retrieve a specific cell
vacc_df.location[333]
# Out:
# 'Austria'

# %%
#retrieve two columns
vacc_df[['location','date']]
# Out:
#           location        date
# 0      Afghanistan  2021-02-22
# 1      Afghanistan  2021-02-23
# 2      Afghanistan  2021-02-24
# 3      Afghanistan  2021-02-25
# 4      Afghanistan  2021-02-26
# ...            ...         ...
# 24325     Zimbabwe  2021-05-30
# 24326     Zimbabwe  2021-05-31
# 24327     Zimbabwe  2021-06-01
# 24328     Zimbabwe  2021-06-02
# 24329     Zimbabwe  2021-06-03
#
# [24330 rows x 2 columns]

# %% [markdown]
# #### Seletcting subsets of rows and columns
#
# One way to do that is iloc.
#
# `.iloc` - selects subsets of rows and columns by integer location only

# %%
#Rows:
#vacc_df.iloc[0]  #first row
vacc_df.iloc[-1] #last row
# Out:
# location                                 Zimbabwe
# iso_code                                      ZWE
# date                                   2021-06-03
# total_vaccinations                     1.0485e+06
# people_vaccinated                          684164
# people_fully_vaccinated                    364340
# daily_vaccinations_raw                       8290
# daily_vaccinations                          13588
# total_vaccinations_per_hundred               7.05
# people_vaccinated_per_hundred                 4.6
# people_fully_vaccinated_per_hundred          2.45
# daily_vaccinations_per_million                914
# Name: 24329, dtype: object

# %% [markdown]
# The : operator
#
#  - when used alone it means "everything"
#
# - also used to indicate a ***slice*** of values

# %%
vacc_df.iloc[1:2] # second and third row
vacc_df.iloc[[-1,2,22]] #a few specific rows

# Columns:
vacc_df.iloc[:,0] # first column of data frame  
vacc_df.iloc[:,1] # second column of data frame  
vacc_df.iloc[:,-1] # last column of data frame

#Rows and columns
vacc_df.iloc[0:5] # first five rows of dataframe
vacc_df.iloc[:, 0:2] # first two columns of data frame with all rows
vacc_df.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
# Out:
#        location  people_fully_vaccinated  daily_vaccinations_raw
# 0   Afghanistan                      NaN                     NaN
# 3   Afghanistan                      NaN                     NaN
# 6   Afghanistan                      NaN                     NaN
# 24  Afghanistan                      NaN                     NaN

# %%
vacc_df.iloc[0:19]
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 0   Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1   Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2   Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3   Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4   Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5   Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6   Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7   Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8   Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9   Afghanistan      AFG  2021-03-03                 NaN                NaN
# 10  Afghanistan      AFG  2021-03-04                 NaN                NaN
# 11  Afghanistan      AFG  2021-03-05                 NaN                NaN
# 12  Afghanistan      AFG  2021-03-06                 NaN                NaN
# 13  Afghanistan      AFG  2021-03-07                 NaN                NaN
# 14  Afghanistan      AFG  2021-03-08                 NaN                NaN
# 15  Afghanistan      AFG  2021-03-09                 NaN                NaN
# 16  Afghanistan      AFG  2021-03-10                 NaN                NaN
# 17  Afghanistan      AFG  2021-03-11                 NaN                NaN
# 18  Afghanistan      AFG  2021-03-12                 NaN                NaN
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN              1367.0
# 2                       NaN                     NaN              1367.0
# 3                       NaN                     NaN              1367.0
# 4                       NaN                     NaN              1367.0
# 5                       NaN                     NaN              1367.0
# 6                       NaN                     NaN              1367.0
# 7                       NaN                     NaN              1580.0
# 8                       NaN                     NaN              1794.0
# 9                       NaN                     NaN              2008.0
# 10                      NaN                     NaN              2221.0
# 11                      NaN                     NaN              2435.0
# 12                      NaN                     NaN              2649.0
# 13                      NaN                     NaN              2862.0
# 14                      NaN                     NaN              2862.0
# 15                      NaN                     NaN              2862.0
# 16                      NaN                     NaN              2862.0
# 17                      NaN                     NaN              2862.0
# 18                      NaN                     NaN              2862.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.00                           0.00
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                             0.02                           0.02
# 7                              NaN                            NaN
# 8                              NaN                            NaN
# 9                              NaN                            NaN
# 10                             NaN                            NaN
# 11                             NaN                            NaN
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
#
#     people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                   NaN                             NaN
# 1                                   NaN                            35.0
# 2                                   NaN                            35.0
# 3                                   NaN                            35.0
# 4                                   NaN                            35.0
# 5                                   NaN                            35.0
# 6                                   NaN                            35.0
# 7                                   NaN                            41.0
# 8                                   NaN                            46.0
# 9                                   NaN                            52.0
# 10                                  NaN                            57.0
# 11                                  NaN                            63.0
# 12                                  NaN                            68.0
# 13                                  NaN                            74.0
# 14                                  NaN                            74.0
# 15                                  NaN                            74.0
# 16                                  NaN                            74.0
# 17                                  NaN                            74.0
# 18                                  NaN                            74.0

# %% [markdown]
# What if I want to select the 'daily_vaccinations' column, but I don't remember which column it is?

# %% [markdown]
# Use `.loc`
#
# `.loc` - selects subsets of rows and columns by label only. Allowed inputs are:
#
# - A single label, e.g. 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
#
# - A list or array of labels, e.g. ['a', 'b', 'c'].
#
# - A slice object with labels, e.g. 'a':'f'.

# %%
vacc_df.loc[:,'daily_vaccinations']
# Out:
# 0            NaN
# 1         1367.0
# 2         1367.0
# 3         1367.0
# 4         1367.0
#           ...
# 24325    14420.0
# 24326    15022.0
# 24327    14756.0
# 24328    14739.0
# 24329    13588.0
# Name: daily_vaccinations, Length: 24330, dtype: float64

# %% [markdown]
# I'm missing the location. Let's add it.

# %%
vacc_df.loc[0:3,['location','daily_vaccinations']]

#vacc_df.loc[0:4:,['location', 'total_vaccinations']]  this is to select specific rows
# Out:
#       location  daily_vaccinations
# 0  Afghanistan                 NaN
# 1  Afghanistan              1367.0
# 2  Afghanistan              1367.0
# 3  Afghanistan              1367.0

# %% [markdown]
# Semantics are similar to iloc. But note:
#
# - `iloc` excludes the last element.  `df.iloc[0:1000]` will return entries 0...999
# - `loc`, includes the last element.  `df.loc[0:1000]` will return entries 0...1000
#
# you try it! What is the difference between:
#
# > vacc_df.iloc[0:5]
#
# > vacc_df.loc[0:5]

# %%
 vacc_df.iloc[0:5]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
vacc_df.loc[0:5]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
# 5                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
# 5                                  NaN                            35.0

# %% [markdown]
# ---
# ---
#
# Now you:
#
# what do you do to select:
#
# a. first five rows?
#
# b. first two columns, all rows?
#
# c. 1st and 3rd row and 2nd and 4th column?
#
# ---
# ---

# %% [markdown]
# a. the first five rows are:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
vacc_df.iloc [:,0:2]

# %%
vacc_df.iloc[[1,3],[2,4]]

# %% [markdown]
# ---
# A summary of the functions in this unit:
#
# * `.iloc` - selects rows and columns by integer location
# * `.loc` - selects rows and columns by label location

# %% [markdown]
# Note: indexing operators as the ones working on dictionaries, will also work in pandas. But for more advanced operations, better get used to loc and iloc.
#
# ---

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## 4. Conditional selection

# %%
vacc_df.loc[:,'location'] == 'Israel'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24325    False
# 24326    False
# 24327    False
# 24328    False
# 24329    False
# Name: location, Length: 24330, dtype: bool

# %% [markdown]
# This creates a series of true/false
#
# We can insert this into data to select only that task:

# %%
vacc_df[vacc_df.loc[:,'location'] == 'Israel']
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 10719   Israel      ISR  2020-12-19                60.0               60.0
# 10720   Israel      ISR  2020-12-20              7419.0             7419.0
# 10721   Israel      ISR  2020-12-21             32303.0            32303.0
# 10722   Israel      ISR  2020-12-22             76915.0            76915.0
# 10723   Israel      ISR  2020-12-23            139748.0           139748.0
# ...        ...      ...         ...                 ...                ...
# 10881   Israel      ISR  2021-05-30          10580452.0          5449716.0
# 10882   Israel      ISR  2021-05-31          10583905.0          5451231.0
# 10883   Israel      ISR  2021-06-01          10586718.0          5452394.0
# 10884   Israel      ISR  2021-06-02          10589163.0          5453562.0
# 10885   Israel      ISR  2021-06-03          10591833.0          5455004.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 10719                      NaN                     NaN                 NaN
# 10720                      NaN                  7359.0              7359.0
# 10721                      NaN                 24884.0             16122.0
# 10722                      NaN                 44612.0             25618.0
# 10723                      NaN                 62833.0             34922.0
# ...                        ...                     ...                 ...
# 10881                5130736.0                  3373.0              3268.0
# 10882                5132674.0                  3453.0              2993.0
# 10883                5134324.0                  2813.0              2821.0
# 10884                5135601.0                  2445.0              2672.0
# 10885                5136829.0                  2670.0              2407.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 10719                            0.00                           0.00
# 10720                            0.09                           0.09
# 10721                            0.37                           0.37
# 10722                            0.89                           0.89
# 10723                            1.61                           1.61
# ...                               ...                            ...
# 10881                          122.24                          62.96
# 10882                          122.28                          62.98
# 10883                          122.31                          62.99
# 10884                          122.34                          63.01
# 10885                          122.37                          63.02
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 10719                                  NaN                             NaN
# 10720                                  NaN                           850.0
# 10721                                  NaN                          1863.0
# 10722                                  NaN                          2960.0
# 10723                                  NaN                          4035.0
# ...                                    ...                             ...
# 10881                                59.28                           378.0
# 10882                                59.30                           346.0
# 10883                                59.32                           326.0
# 10884                                59.33                           309.0
# 10885                                59.35                           278.0
#
# [167 rows x 12 columns]

# %% [markdown]
# Another way:

# %%
vacc_df.loc[vacc_df.location == 'Israel']
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 10719   Israel      ISR  2020-12-19                60.0               60.0
# 10720   Israel      ISR  2020-12-20              7419.0             7419.0
# 10721   Israel      ISR  2020-12-21             32303.0            32303.0
# 10722   Israel      ISR  2020-12-22             76915.0            76915.0
# 10723   Israel      ISR  2020-12-23            139748.0           139748.0
# ...        ...      ...         ...                 ...                ...
# 10881   Israel      ISR  2021-05-30          10580452.0          5449716.0
# 10882   Israel      ISR  2021-05-31          10583905.0          5451231.0
# 10883   Israel      ISR  2021-06-01          10586718.0          5452394.0
# 10884   Israel      ISR  2021-06-02          10589163.0          5453562.0
# 10885   Israel      ISR  2021-06-03          10591833.0          5455004.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 10719                      NaN                     NaN                 NaN
# 10720                      NaN                  7359.0              7359.0
# 10721                      NaN                 24884.0             16122.0
# 10722                      NaN                 44612.0             25618.0
# 10723                      NaN                 62833.0             34922.0
# ...                        ...                     ...                 ...
# 10881                5130736.0                  3373.0              3268.0
# 10882                5132674.0                  3453.0              2993.0
# 10883                5134324.0                  2813.0              2821.0
# 10884                5135601.0                  2445.0              2672.0
# 10885                5136829.0                  2670.0              2407.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 10719                            0.00                           0.00
# 10720                            0.09                           0.09
# 10721                            0.37                           0.37
# 10722                            0.89                           0.89
# 10723                            1.61                           1.61
# ...                               ...                            ...
# 10881                          122.24                          62.96
# 10882                          122.28                          62.98
# 10883                          122.31                          62.99
# 10884                          122.34                          63.01
# 10885                          122.37                          63.02
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 10719                                  NaN                             NaN
# 10720                                  NaN                           850.0
# 10721                                  NaN                          1863.0
# 10722                                  NaN                          2960.0
# 10723                                  NaN                          4035.0
# ...                                    ...                             ...
# 10881                                59.28                           378.0
# 10882                                59.30                           346.0
# 10883                                59.32                           326.0
# 10884                                59.33                           309.0
# 10885                                59.35                           278.0
#
# [167 rows x 12 columns]

# %% [markdown]
# Select two countries:

# %%
two_countries = vacc_df.loc[(vacc_df.location == 'Israel') | (vacc_df.location == 'Denmark')]
two_countries
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 5458   Denmark      DNK  2020-12-17                 1.0                1.0
# 5459   Denmark      DNK  2020-12-18                 NaN                NaN
# 5460   Denmark      DNK  2020-12-19                 2.0                2.0
# 5461   Denmark      DNK  2020-12-20                 NaN                NaN
# 5462   Denmark      DNK  2020-12-21                 3.0                3.0
# ...        ...      ...         ...                 ...                ...
# 10881   Israel      ISR  2021-05-30          10580452.0          5449716.0
# 10882   Israel      ISR  2021-05-31          10583905.0          5451231.0
# 10883   Israel      ISR  2021-06-01          10586718.0          5452394.0
# 10884   Israel      ISR  2021-06-02          10589163.0          5453562.0
# 10885   Israel      ISR  2021-06-03          10591833.0          5455004.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 5458                       NaN                     NaN                 NaN
# 5459                       NaN                     NaN                 0.0
# 5460                       NaN                     NaN                 0.0
# 5461                       NaN                     NaN                 0.0
# 5462                       NaN                     NaN                 0.0
# ...                        ...                     ...                 ...
# 10881                5130736.0                  3373.0              3268.0
# 10882                5132674.0                  3453.0              2993.0
# 10883                5134324.0                  2813.0              2821.0
# 10884                5135601.0                  2445.0              2672.0
# 10885                5136829.0                  2670.0              2407.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 5458                             0.00                           0.00
# 5459                              NaN                            NaN
# 5460                             0.00                           0.00
# 5461                              NaN                            NaN
# 5462                             0.00                           0.00
# ...                               ...                            ...
# 10881                          122.24                          62.96
# 10882                          122.28                          62.98
# 10883                          122.31                          62.99
# 10884                          122.34                          63.01
# 10885                          122.37                          63.02
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 5458                                   NaN                             NaN
# 5459                                   NaN                             0.0
# 5460                                   NaN                             0.0
# 5461                                   NaN                             0.0
# 5462                                   NaN                             0.0
# ...                                    ...                             ...
# 10881                                59.28                           378.0
# 10882                                59.30                           346.0
# 10883                                59.32                           326.0
# 10884                                59.33                           309.0
# 10885                                59.35                           278.0
#
# [336 rows x 12 columns]

# %% [markdown]
# only the indexs of the tasks:

# %%
two_countries.index.values
# Out:
# array([ 5458,  5459,  5460,  5461,  5462,  5463,  5464,  5465,  5466,
#         5467,  5468,  5469,  5470,  5471,  5472,  5473,  5474,  5475,
#         5476,  5477,  5478,  5479,  5480,  5481,  5482,  5483,  5484,
#         5485,  5486,  5487,  5488,  5489,  5490,  5491,  5492,  5493,
#         5494,  5495,  5496,  5497,  5498,  5499,  5500,  5501,  5502,
#         5503,  5504,  5505,  5506,  5507,  5508,  5509,  5510,  5511,
#         5512,  5513,  5514,  5515,  5516,  5517,  5518,  5519,  5520,
#         5521,  5522,  5523,  5524,  5525,  5526,  5527,  5528,  5529,
#         5530,  5531,  5532,  5533,  5534,  5535,  5536,  5537,  5538,
#         5539,  5540,  5541,  5542,  5543,  5544,  5545,  5546,  5547,
#         5548,  5549,  5550,  5551,  5552,  5553,  5554,  5555,  5556,
#         5557,  5558,  5559,  5560,  5561,  5562,  5563,  5564,  5565,
#         5566,  5567,  5568,  5569,  5570,  5571,  5572,  5573,  5574,
#         5575,  5576,  5577,  5578,  5579,  5580,  5581,  5582,  5583,
#         5584,  5585,  5586,  5587,  5588,  5589,  5590,  5591,  5592,
#         5593,  5594,  5595,  5596,  5597,  5598,  5599,  5600,  5601,
#         5602,  5603,  5604,  5605,  5606,  5607,  5608,  5609,  5610,
#         5611,  5612,  5613,  5614,  5615,  5616,  5617,  5618,  5619,
#         5620,  5621,  5622,  5623,  5624,  5625,  5626, 10719, 10720,
#        10721, 10722, 10723, 10724, 10725, 10726, 10727, 10728, 10729,
#        10730, 10731, 10732, 10733, 10734, 10735, 10736, 10737, 10738,
#        10739, 10740, 10741, 10742, 10743, 10744, 10745, 10746, 10747,
#        10748, 10749, 10750, 10751, 10752, 10753, 10754, 10755, 10756,
#        10757, 10758, 10759, 10760, 10761, 10762, 10763, 10764, 10765,
#        10766, 10767, 10768, 10769, 10770, 10771, 10772, 10773, 10774,
#        10775, 10776, 10777, 10778, 10779, 10780, 10781, 10782, 10783,
#        10784, 10785, 10786, 10787, 10788, 10789, 10790, 10791, 10792,
#        10793, 10794, 10795, 10796, 10797, 10798, 10799, 10800, 10801,
#        10802, 10803, 10804, 10805, 10806, 10807, 10808, 10809, 10810,
#        10811, 10812, 10813, 10814, 10815, 10816, 10817, 10818, 10819,
#        10820, 10821, 10822, 10823, 10824, 10825, 10826, 10827, 10828,
#        10829, 10830, 10831, 10832, 10833, 10834, 10835, 10836, 10837,
#        10838, 10839, 10840, 10841, 10842, 10843, 10844, 10845, 10846,
#        10847, 10848, 10849, 10850, 10851, 10852, 10853, 10854, 10855,
#        10856, 10857, 10858, 10859, 10860, 10861, 10862, 10863, 10864,
#        10865, 10866, 10867, 10868, 10869, 10870, 10871, 10872, 10873,
#        10874, 10875, 10876, 10877, 10878, 10879, 10880, 10881, 10882,
#        10883, 10884, 10885], dtype=int64)

# %% [markdown]
# the index in the first place:

# %%
two_countries.index.values[0]
# Out:
# 5458

# %% [markdown]
# how many rows for the two countries?

# %%
two_countries.count()
# Out:
# location                               336
# iso_code                               336
# date                                   336
# total_vaccinations                     333
# people_vaccinated                      333
# people_fully_vaccinated                302
# daily_vaccinations_raw                 328
# daily_vaccinations                     334
# total_vaccinations_per_hundred         333
# people_vaccinated_per_hundred          333
# people_fully_vaccinated_per_hundred    302
# daily_vaccinations_per_million         334
# dtype: int64

# %% [markdown]
# At the end of the file we have some world data.
#
# Use str.contains if you're not sure how this location is called

# %%
vacc_df[vacc_df['location'].str.contains('World')]
# Out:
#       location  iso_code        date  total_vaccinations  people_vaccinated  \
# 23968    World  OWID_WRL  2020-12-02        0.000000e+00                0.0
# 23969    World  OWID_WRL  2020-12-03        0.000000e+00                0.0
# 23970    World  OWID_WRL  2020-12-04        0.000000e+00                0.0
# 23971    World  OWID_WRL  2020-12-05        0.000000e+00                0.0
# 23972    World  OWID_WRL  2020-12-06        0.000000e+00                0.0
# ...        ...       ...         ...                 ...                ...
# 24148    World  OWID_WRL  2021-05-31        1.943702e+09        843940538.0
# 24149    World  OWID_WRL  2021-06-01        1.982642e+09        855335435.0
# 24150    World  OWID_WRL  2021-06-02        2.021920e+09        865905745.0
# 24151    World  OWID_WRL  2021-06-03        2.056464e+09        876544294.0
# 24152    World  OWID_WRL  2021-06-04        2.091618e+09        886972594.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 23968                      NaN                     NaN                 NaN
# 23969                      NaN                     0.0                 0.0
# 23970                      NaN                     0.0                 0.0
# 23971                      NaN                     0.0                 0.0
# 23972                      NaN                     0.0                 0.0
# ...                        ...                     ...                 ...
# 24148              432929856.0              36613344.0          34211634.0
# 24149              439589762.0              38940302.0          34036634.0
# 24150              445243447.0              39278305.0          34715310.0
# 24151              450379391.0              34544222.0          34788074.0
# 24152              454246457.0              35153221.0          35149866.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 23968                            0.00                           0.00
# 23969                            0.00                           0.00
# 23970                            0.00                           0.00
# 23971                            0.00                           0.00
# 23972                            0.00                           0.00
# ...                               ...                            ...
# 24148                           24.94                          10.83
# 24149                           25.44                          10.97
# 24150                           25.94                          11.11
# 24151                           26.38                          11.25
# 24152                           26.83                          11.38
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 23968                                  NaN                             NaN
# 23969                                  NaN                             0.0
# 23970                                  NaN                             0.0
# 23971                                  NaN                             0.0
# 23972                                  NaN                             0.0
# ...                                    ...                             ...
# 24148                                 5.55                          4389.0
# 24149                                 5.64                          4367.0
# 24150                                 5.71                          4454.0
# 24151                                 5.78                          4463.0
# 24152                                 5.83                          4509.0
#
# [185 rows x 12 columns]

# %% [markdown]
# Remove the world data:

# %%
vacc_df_noWorld = vacc_df.loc[vacc_df.location != 'World']
vacc_df_noWorld.tail()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 24325  Zimbabwe      ZWE  2021-05-30           1011973.0           670755.0
# 24326  Zimbabwe      ZWE  2021-05-31           1020078.0           675678.0
# 24327  Zimbabwe      ZWE  2021-06-01           1031281.0           678003.0
# 24328  Zimbabwe      ZWE  2021-06-02           1040214.0           682242.0
# 24329  Zimbabwe      ZWE  2021-06-03           1048504.0           684164.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 24325                 341218.0                  9508.0             14420.0
# 24326                 344400.0                  8105.0             15022.0
# 24327                 353278.0                 11203.0             14756.0
# 24328                 357972.0                  8933.0             14739.0
# 24329                 364340.0                  8290.0             13588.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 24325                            6.81                           4.51
# 24326                            6.86                           4.55
# 24327                            6.94                           4.56
# 24328                            7.00                           4.59
# 24329                            7.05                           4.60
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 24325                                 2.30                           970.0
# 24326                                 2.32                          1011.0
# 24327                                 2.38                           993.0
# 24328                                 2.41                           992.0
# 24329                                 2.45                           914.0

# %% [markdown]
# Find the country with the maximum vaccinations:

# %%
max_vacc = vacc_df_noWorld.total_vaccinations.max()
max_vacc
# Out:
# 1170681538.0

# %%
vacc_df_noWorld.loc[vacc_df_noWorld.total_vaccinations == max_vacc]
# Out:
#      location  iso_code        date  total_vaccinations  people_vaccinated  \
# 1314     Asia  OWID_ASI  2021-06-04        1.170682e+09        296681399.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1314              109025372.0              28233005.0          26007413.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1314                           25.23                           6.39
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 1314                                 2.35                          5605.0

# %% [markdown]
# What do you think this function does?

# %%
vacc_df_noWorld.total_vaccinations.mean()
# Out:
# 21346240.488578152

# %% [markdown]
# ----
# #### Your turn:

# %% [markdown]
# Select the number of daily vaccinations in Israel on date 2021-02-06 (hint: use &)

# %%
vacc_df.loc[(vacc_df.location == 'Israel') & (vacc_df.date == '2021-02-06')]
# Out:
# 3197    99682.0
# Name: daily_vaccinations, dtype: float64

# %% [markdown]
# Find all the countries with more than 3000000 vaccinations

# %%
vacc_df_noWorld.loc[(vacc_df.daily_vaccinations > 300000)]
# Out:
#                   location  iso_code        date  total_vaccinations  \
# 178                 Africa  OWID_AFR  2021-03-27        1.030312e+07
# 179                 Africa  OWID_AFR  2021-03-28        1.056197e+07
# 180                 Africa  OWID_AFR  2021-03-29        1.077488e+07
# 181                 Africa  OWID_AFR  2021-03-30        1.097167e+07
# 221                 Africa  OWID_AFR  2021-05-09        2.119979e+07
# ...                    ...       ...         ...                 ...
# 23396  Upper middle income  OWID_UMC  2021-05-31        9.121940e+08
# 23397  Upper middle income  OWID_UMC  2021-06-01        9.372860e+08
# 23398  Upper middle income  OWID_UMC  2021-06-02        9.645319e+08
# 23399  Upper middle income  OWID_UMC  2021-06-03        9.877467e+08
# 23400  Upper middle income  OWID_UMC  2021-06-04        1.011464e+09
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 178            6887741.0                3606163.0                325837.0
# 179            7143927.0                3608826.0                258849.0
# 180            7230693.0                3743035.0                212915.0
# 181            7312045.0                3870510.0                196785.0
# 221           15988514.0                5518752.0                729471.0
# ...                  ...                      ...                     ...
# 23396        164264705.0               89360763.0              26389746.0
# 23397        167079529.0               91143766.0              25091987.0
# 23398        169908703.0               92517360.0              27245846.0
# 23399        173091645.0               93822256.0              23214796.0
# 23400        175126517.0               94434520.0              23717677.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 178              301268.0                            0.77
# 179              335169.0                            0.79
# 180              348122.0                            0.80
# 181              355345.0                            0.82
# 221              351787.0                            1.58
# ...                   ...                             ...
# 23396          23498379.0                           34.36
# 23397          22696062.0                           35.31
# 23398          23353237.0                           36.33
# 23399          23655502.0                           37.21
# 23400          23901596.0                           38.10
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 178                             0.51                                 0.27
# 179                             0.53                                 0.27
# 180                             0.54                                 0.28
# 181                             0.55                                 0.29
# 221                             1.19                                 0.41
# ...                              ...                                  ...
# 23396                           6.19                                 3.37
# 23397                           6.29                                 3.43
# 23398                           6.40                                 3.48
# 23399                           6.52                                 3.53
# 23400                           6.60                                 3.56
#
#        daily_vaccinations_per_million
# 178                             225.0
# 179                             250.0
# 180                             260.0
# 181                             265.0
# 221                             262.0
# ...                               ...
# 23396                          8851.0
# 23397                          8549.0
# 23398                          8797.0
# 23399                          8910.0
# 23400                          9003.0
#
# [2334 rows x 12 columns]

# %% [markdown]
# ---
# Summary of the functions in this unit:
#
# * `.index.values` - the row indexes of this part of the dataframes
# * `.str.contains` - selects rows and columns that contain a string
# * `.max` - maximum value
# * `.mean` - average value
# * `.count` - the number of rows that contain a value
